# %%
import numpy as np
import pandas as pd
from nltk import pos_tag
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
import random 
from nltk.corpus import stopwords
import string
import nltk
import re

# %%
fraud_df=pd.read_csv('./datasets/fraudulent_text_data.csv')

# %%
fraud_df.frauds = fraud_df.frauds.str.replace(" ’ ","").str.replace(" ‘ ","")

# %%
fraud_df.frauds.to_list()
# Out:
# ['How Machine Learning is Solving Fraud Detection in Finance',
#  'The Advantages and Disadvantages of Using Payoneer as a Freelancer',
#  'Amazon Fraud DetectorAFD launched AFDLists to optimize fraud prevention strategies',
#  'New Protections for Food Benefits Stolen by Skimmers',
#  'Amazon Fraud Detector introduces Cold Start model training for customers with limited historical data',
#  'Digital Payments The Benefits, How To Use Them In Your Business And What To Look For In A Provider',
#  'EBay buys AI fraud detection company PM Shield',
#  "It's Illegal to Be a 'Money Mule,' Whether You Know It or Not",
#  'Transaction Monitoring Market is Likely to Rise at USD  Billion Globally by , Size, Share, Trends, Demand, Growth and Competitors Analysis',
#  ' Statistical Paradoxes Data Scientists Should Know',
#  "Removing Phantoms With Technology and 'Gentle' Persuasion",
#  'Radiant Logic Signs Definitive Agreement to Acquire Brainwave GRC',
# ...

# %%
fraud_df.frauds = fraud_df.frauds.str.lower()

# %%
fraud_df.frauds = fraud_df.frauds.str.split()
fraud_df.frauds
# Out:
# 0       [how, machine, learning, is, solving, fraud, d...
# 1       [the, advantages, and, disadvantages, of, usin...
# 2       [amazon, fraud, detectorafd, launched, afdlist...
# 3       [new, protections, for, food, benefits, stolen...
# 4       [amazon, fraud, detector, introduces, cold, st...
#                               ...
# 1035    [on, the, fednow, service, what, to, expect, f...
# 1036    [quarter, of, crypto, tokens, linked, to, pump...
# 1037    [couple, whose, toronto, home, sold, without, ...
# 1038    [granderson, of, course, authorities, should, ...
# 1039        [seon, acquires, aml, specialist, complytron]
# Name: frauds, Length: 1040, dtype: object

# %%
sw = set(stopwords.words('english'))
punctuations = list(string.punctuation)
sw.update(punctuations)

# %%
sp_char='[@_!#$%^&*()<>?/\|}{~£+:.-]™"'
lemmatizer = WordNetLemmatizer()
def clean_data(sentences):
    clean_sentences=[]
    for sentence in sentences:
        clean_sentence = []
        for word in sentence:
            w = word.strip()
            if (w not in sw) and (w not in sp_char) and w:
                clean_word = w
                clean_sentence.append(clean_word)
        clean_sentences.append(clean_sentence)
    return clean_sentences

# %%
fraud_cleaned = clean_data(fraud_df.frauds.to_list())
fraud_cleaned
# Out:
# [['machine', 'learning', 'solving', 'fraud', 'detection', 'finance'],
#  ['advantages', 'disadvantages', 'using', 'payoneer', 'freelancer'],
#  ['amazon',
#   'fraud',
#   'detectorafd',
#   'launched',
#   'afdlists',
#   'optimize',
#   'fraud',
#   'prevention',
#   'strategies'],
#  ['new', 'protections', 'food', 'benefits', 'stolen', 'skimmers'],
#  ['amazon',
#   'fraud',
#   'detector',
#   'introduces',
#   'cold',
#   'start',
#   'model',
#   'training',
#   'customers',
#   'limited',
#   'historical',
#   'data'],
#  ['digital', 'payments', 'benefits,', 'use', 'business', 'look', 'provider'],
#  ['ebay', 'buys', 'ai', 'fraud', 'detection', 'company', 'pm', 'shield'],
#  ['illegal', "'money", "mule,'", 'whether', 'know'],
#  ['transaction',
#   'monitoring',
#   'market',
#   'likely',
#   'rise',
#   'usd',
#   'billion',
#   'globally',
#   'size,',
#   'share,',
#   'trends,',
#   'demand,',
#   'growth',
#   'competitors',
#   'analysis'],
# ...

# %%
cleaned_data=[]
for string in fraud_cleaned:
    cleaned_data.append(','.join(string))

# %%
df= pd.DataFrame({'frauds':cleaned_data})

# %%
text_data=df['frauds'].str.split(',',expand=True)

# %%
text_data.head()
# Out:
#            0              1            2           3           4         5   \
# 0     machine       learning      solving       fraud   detection   finance
# 1  advantages  disadvantages        using    payoneer  freelancer      None
# 2      amazon          fraud  detectorafd    launched    afdlists  optimize
# 3         new    protections         food    benefits      stolen  skimmers
# 4      amazon          fraud     detector  introduces        cold     start
#
#       6           7           8        9           10    11    12    13    14  \
# 0   None        None        None     None        None  None  None  None  None
# 1   None        None        None     None        None  None  None  None  None
# 2  fraud  prevention  strategies     None        None  None  None  None  None
# 3   None        None        None     None        None  None  None  None  None
# 4  model    training   customers  limited  historical  data  None  None  None
#
#      15    16    17    18
# ...

# %%
text_data.to_csv('./Cleaned Dataset/cleaned_text_data.csv',index=False)
